# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.5.1+cu121)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)

# %% [markdown]
# # Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np
import random
from datetime import datetime
import copy
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %% [markdown]
# # REPRODUCIBILITY

# %%
def set_seed(seed=42):
    """
    Set all relevant random seeds for reproducibility.
    """
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)

set_seed(42)

# %% [markdown]
# # DEVICE CONFIGURATION

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# # DATA LOADING AND TRANSFORMS

# %%
#apply data augmentations and normalisation CIFAR-10 training data
train_transform = transforms.Compose([
    # Cropping
    transforms.RandomCrop(32, padding=4),
    # Flipping
    transforms.RandomHorizontalFlip(),
    # Rotation
    transforms.RandomRotation(15), 
    # Color Jitter
    transforms.ColorJitter(          
        brightness=0.2,
        contrast=0.2,
        saturation=0.2,
        hue=0.1
    ),
    # normalisation
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2470, 0.2435, 0.2616)),
    #Erasing
    transforms.RandomErasing(
        p=0.5,
        scale=(0.02, 0.33),
        ratio=(0.3, 3.3),
        value=0
    )
])

# Normalise Test data
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2470, 0.2435, 0.2616))
])

# Download CIFAR-10 dataset
train_dataset = torchvision.datasets.CIFAR10(
    root='data/',
    train=True,
    download=True,
    transform=train_transform
)

test_dataset = torchvision.datasets.CIFAR10(
    root='data/',
    train=False,
    download=True,
    transform=test_transform
)

# We can split off a validation set from the training data
val_size = 5000
train_size = len(train_dataset) - val_size
train_data, val_data = random_split(train_dataset, [train_size, val_size])

print(f"Length of Training Data: {len(train_data)}")
print(f"Length of Validation Data: {len(val_data)}")
print(f"Length of Test Data: {len(test_dataset)}")

# Create DataLoaders
batch_size = 128
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True,  num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_data,   batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:13<00:00, 13.0MB/s]
# Extracting data/cifar-10-python.tar.gz to data/
# Files already downloaded and verified
# Length of Training Data: 45000
# Length of Validation Data: 5000
# Length of Test Data: 10000

# %% [markdown]
# # CNN MODEL (VGG16-INSPIRED)

# %%
class CNN_model(nn.Module):
    """
    A simplified VGG-like network for CIFAR-10 classification:
      - 2 Conv layers, BatchNorm, MaxPool, Dropout
      - Repeat blocks with increasing channels: 32 -> 64 -> 128 -> 256
      - Fully connected layer for classification into 10 classes
    """
    def __init__(self, num_classes=10):
        super(CNN_model, self).__init__()

        # Block 1: 32 filters
        self.block1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.2)
        )

        # Block 2: 64 filters
        self.block2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.3)
        )

        # Block 3: 128 filters
        self.block3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.4)
        )

        # Block 4: 256 filters
        self.block4 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(256),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5)
        )


        # Classification head
        # After the 4th block, the spatial dimension is 2x2 (for CIFAR-10: 32 -> 16 -> 8 -> 4 -> 2).
        self.classifier = nn.Sequential(
            # Flatten
            nn.Linear(256 * 2 * 2, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    # confirm the spatial dimension is 2x2
    def forward(self, x):
        x = self.block1(x)        # [B, 32, 16, 16]
        x = self.block2(x)        # [B, 64, 8, 8]
        x = self.block3(x)        # [B, 128, 4, 4]
        x = self.block4(x)        # [B, 256, 2, 2]
        x = x.view(x.size(0), -1) # Flatten
        x = self.classifier(x)    # [B, 10]
        return x

# %% [markdown]
# # EVALUATION METRICS AND TRAIN/VALIDATION LOOP

# %%
def accuracy(outputs, labels):
    """
    Compute the batch accuracy.
    """
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

@torch.no_grad()
def evaluate(model, val_loader):
    """
    Evaluate the model on the validation set.
    Returns average loss and accuracy.
    """
    model.eval()
    losses = []
    accs = []

    for images, labels in val_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = F.cross_entropy(outputs, labels)
        acc = accuracy(outputs, labels)

        losses.append(loss.item())
        accs.append(acc.item())

    val_loss = np.mean(losses)
    val_acc  = np.mean(accs)
    return val_loss, val_acc

# %%
# fit with early stopping
def fit(
    model,
    train_loader,
    val_loader,
    epochs=250,
    patience_lr=10,     # patience for ReduceLROnPlateau
    patience_es=20,     # patience for EarlyStopping
    factor=0.5,         # LR reduction factor
    optimizer_cls=torch.optim.Adam,
    optimizer_kwargs=None
):
    """
    Train the model with ReduceLROnPlateau and EarlyStopping.

    Arguments:
    ----------
    model           : The PyTorch model to train.
    train_loader    : DataLoader for training data.
    val_loader      : DataLoader for validation data.
    epochs          : Max number of epochs to run.
    patience_lr     : # of epochs with no val_loss improvement before reducing LR.
    patience_es     : # of epochs with no val_loss improvement before early stopping.
    factor          : Factor by which to reduce LR on plateau (e.g. 0.5 = half).
    optimizer_cls   : Optimizer class (e.g., torch.optim.Adam).
    optimizer_kwargs: Dictionary of parameters for the optimizer.

    Returns:
    --------
    history : List of dicts with training info per epoch.
    """

    if optimizer_kwargs is None:
        optimizer_kwargs = {"lr": 1e-3, "weight_decay": 0.0}

    # Instantiate the optimizer
    optimizer = optimizer_cls(model.parameters(), **optimizer_kwargs)

    # Scheduler: reduces LR when val_loss has stopped improving
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=factor,
                                  patience=patience_lr, verbose=True)

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    epochs_no_improve = 0  # For early stopping

    history = []

    for epoch in range(1, epochs+1):
        start_time = datetime.now()
        model.train()
        train_losses = []
        train_accs = []

        # Training loop
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = F.cross_entropy(outputs, labels)
            acc = accuracy(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_losses.append(loss.item())
            train_accs.append(acc.item())

        # Evaluate on validation set
        val_loss, val_acc = evaluate(model, val_loader)

        # Mean metrics for this epoch
        train_loss_epoch = np.mean(train_losses)
        train_acc_epoch  = np.mean(train_accs)

        # Check if validation loss improved
        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        # Print epoch results
        print(f"Epoch [{epoch}/{epochs}] "
              f"Train Loss: {train_loss_epoch:.4f}, "
              f"Train Acc: {train_acc_epoch:.4f}, "
              f"Val Loss: {val_loss:.4f}, "
              f"Val Acc: {val_acc:.4f}, "
              f"Time: {datetime.now() - start_time}")

        # Append to history
        history.append({
            'epoch': epoch,
            'train_loss': train_loss_epoch,
            'train_acc': train_acc_epoch,
            'val_loss': val_loss,
            'val_acc': val_acc
        })

        # Step the scheduler
        # (it expects a metric to monitor, here we use val_loss)
        scheduler.step(val_loss)

        # Check early stopping condition
        if epochs_no_improve >= patience_es:
            print(f"EarlyStopping triggered! No improvement for {patience_es} epochs.")
            break

    # Restore best weights
    model.load_state_dict(best_model_wts)
    return history

# %% [markdown]
# # TESTING & PLOT FUNCTION

# %%
@torch.no_grad()
def test_model(model, test_loader):
    """
    Evaluate the model on the test dataset.
    """
    model.eval()
    losses = []
    accs = []
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = F.cross_entropy(outputs, labels)
        acc = accuracy(outputs, labels)

        losses.append(loss.item())
        accs.append(acc.item())

    test_loss = np.mean(losses)
    test_acc  = np.mean(accs)
    return test_loss, test_acc

def plot_history(hist):
    """
    Plot training and validation loss/accuracy curves over epochs.
    """
    epochs_list = [x['epoch'] for x in hist]

    train_loss = [x['train_loss'] for x in hist]
    val_loss   = [x['val_loss'] for x in hist]
    train_acc  = [x['train_acc'] for x in hist]
    val_acc    = [x['val_acc'] for x in hist]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,5))

    # Loss subplot
    ax1.plot(epochs_list, train_loss, label='Train Loss')
    ax1.plot(epochs_list, val_loss, label='Val Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.set_title('Loss Over Epochs')
    ax1.legend()

    # Accuracy subplot
    ax2.plot(epochs_list, train_acc, label='Train Acc')
    ax2.plot(epochs_list, val_acc, label='Val Acc')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.set_title('Accuracy Over Epochs')
    ax2.legend()

    plt.show()

# %% [markdown]
# # HYPERPARAMETER SETUP & TRAINING

# %%
# Instantiate Model 1
model_1 = CNN_model(num_classes=10).to(device)

# Optimizer hyperparams (Adam)
adam_kwargs_1 = {
    "lr": 1e-3,
    "weight_decay": 5e-4  # Strong L2 regularization
}

# Train and validate
history_1 = fit(
    model_1,
    train_loader,
    val_loader,
    epochs=30,                       # 30 epochs
    optimizer_cls=torch.optim.Adam,  # Keep Adam
    optimizer_kwargs=adam_kwargs_1
)

test_loss_1, test_acc_1 = test_model(model_1, test_loader)
print(f"\nTest Loss Model 1: {test_loss_1:.4f}, Test Acc: {test_acc_1:.4f}")
plot_history(history_1)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/30] Train Loss: 1.8144, Train Acc: 0.3272, Val Loss: 1.4970, Val Acc: 0.4596, Time: 0:00:31.655489
# Epoch [2/30] Train Loss: 1.4997, Train Acc: 0.4603, Val Loss: 1.3513, Val Acc: 0.5260, Time: 0:00:28.826132
# Epoch [3/30] Train Loss: 1.3283, Train Acc: 0.5301, Val Loss: 1.1956, Val Acc: 0.5775, Time: 0:00:28.957752
# Epoch [4/30] Train Loss: 1.2231, Train Acc: 0.5708, Val Loss: 1.0858, Val Acc: 0.6197, Time: 0:00:29.227357
# Epoch [5/30] Train Loss: 1.1411, Train Acc: 0.6021, Val Loss: 1.0398, Val Acc: 0.6404, Time: 0:00:29.113923
# Epoch [6/30] Train Loss: 1.0774, Train Acc: 0.6253, Val Loss: 0.9547, Val Acc: 0.6590, Time: 0:00:29.321222
# Epoch [7/30] Train Loss: 1.0364, Train Acc: 0.6433, Val Loss: 0.8959, Val Acc: 0.6889, Time: 0:00:29.414744
# Epoch [8/30] Train Loss: 0.9988, Train Acc: 0.6589, Val Loss: 0.9154, Val Acc: 0.6775, Time: 0:00:29.232304
# Epoch [9/30] Train Loss: 0.9743, Train Acc: 0.6691, Val Loss: 0.8581, Val Acc: 0.7006, Time: 0:00:29.399829
# Epoch [10/30] Train Loss: 0.9531, Train Acc: 0.6745, Val Loss: 0.8767, Val Acc: 0.6918, Time: 0:00:29.404843
# Epoch [11/30] Train Loss: 0.9261, Train Acc: 0.6848, Val Loss: 0.8413, Val Acc: 0.7068, Time: 0:00:29.621192
# Epoch [12/30] Train Loss: 0.9070, Train Acc: 0.6880, Val Loss: 0.7848, Val Acc: 0.7271, Time: 0:00:29.705087
# Epoch [13/30] Train Loss: 0.8905, Train Acc: 0.6982, Val Loss: 0.7899, Val Acc: 0.7258, Time: 0:00:29.407296
# Epoch [14/30] Train Loss: 0.8791, Train Acc: 0.6998, Val Loss: 0.7487, Val Acc: 0.7383, Time: 0:00:29.586838
# Epoch [15/30] Train Loss: 0.8628, Train Acc: 0.7056, Val Loss: 0.8104, Val Acc: 0.7248, Time: 0:00:30.234767
# Epoch [16/30] Train Loss: 0.8572, Train Acc: 0.7087, Val Loss: 0.7007, Val Acc: 0.7582, Time: 0:00:30.511072
# Epoch [17/30] Train Loss: 0.8483, Train Acc: 0.7107, Val Loss: 0.7715, Val Acc: 0.7426, Time: 0:00:29.662593
# Epoch [18/30] Train Loss: 0.8354, Train Acc: 0.7179, Val Loss: 0.7395, Val Acc: 0.7539, Time: 0:00:29.958770
# Epoch [19/30] Train Loss: 0.8249, Train Acc: 0.7182, Val Loss: 0.7155, Val Acc: 0.7543, Time: 0:00:30.500887
# Epoch [20/30] Train Loss: 0.8169, Train Acc: 0.7206, Val Loss: 0.7055, Val Acc: 0.7619, Time: 0:00:30.359957
# Epoch [21/30] Train Loss: 0.8151, Train Acc: 0.7229, Val Loss: 0.6927, Val Acc: 0.7641, Time: 0:00:30.708099
# Epoch [22/30] Train Loss: 0.8019, Train Acc: 0.7256, Val Loss: 0.7043, Val Acc: 0.7553, Time: 0:00:30.086109
# Epoch [23/30] Train Loss: 0.8147, Train Acc: 0.7210, Val Loss: 0.7285, Val Acc: 0.7520, Time: 0:00:30.310123
# Epoch [24/30] Train Loss: 0.7880, Train Acc: 0.7318, Val Loss: 0.6805, Val Acc: 0.7664, Time: 0:00:31.288619
# Epoch [25/30] Train Loss: 0.7935, Train Acc: 0.7297, Val Loss: 0.6987, Val Acc: 0.7602, Time: 0:00:30.477515
# Epoch [26/30] Train Loss: 0.7878, Train Acc: 0.7341, Val Loss: 0.6630, Val Acc: 0.7688, Time: 0:00:29.532040
# Epoch [27/30] Train Loss: 0.7776, Train Acc: 0.7382, Val Loss: 0.6674, Val Acc: 0.7748, Time: 0:00:29.548827
# Epoch [28/30] Train Loss: 0.7761, Train Acc: 0.7371, Val Loss: 0.6814, Val Acc: 0.7584, Time: 0:00:30.346583
# Epoch [29/30] Train Loss: 0.7699, Train Acc: 0.7370, Val Loss: 0.7215, Val Acc: 0.7434, Time: 0:00:29.873766
# Epoch [30/30] Train Loss: 0.7648, Train Acc: 0.7384, Val Loss: 0.6665, Val Acc: 0.7662, Time: 0:00:29.930028
# Training Time: 0:00:29.933004
#
# Test Loss Model 1: 0.4783, Test Acc: 0.8376

# %%
# Using Google colab with A100 GPU (Approximately 75 Minutes - 30 seconds each epoch):
# Test Loss: 0.2863, Test Acc: 0.9067
# 256 batch size

# Now its 128 batch size
# Instantiate your model
model_2 = CNN_model(num_classes=10).to(device)

# For example, let's use Adam with these hyperparams:
adam_kwargs_2 = {
    "lr": 0.001,
    "weight_decay": 1e-4
}

# Train with early stopping and LR scheduler
history_2 = fit(
    model_2,
    train_loader,
    val_loader,
    epochs=150,              # max 150 epochs
    patience_lr=10,          # reduce LR after 10 epochs of no improvement
    patience_es=20,          # stop after 20 epochs of no improvement
    factor=0.5,              # half the LR each time plateau is reached
    optimizer_cls=torch.optim.Adam,
    optimizer_kwargs=adam_kwargs_2
)

test_loss_2, test_acc_2 = test_model(model_2, test_loader)
print(f"\nTest Loss Model 2: {test_loss_2:.4f}, Test Acc: {test_acc_2:.4f}")
plot_history(history_2)
# Out:
# Epoch [1/150] Train Loss: 1.8350, Train Acc: 0.3174, Val Loss: 1.5746, Val Acc: 0.4145, Time: 0:00:29.524472
# Epoch [2/150] Train Loss: 1.5344, Train Acc: 0.4440, Val Loss: 1.3699, Val Acc: 0.5123, Time: 0:00:29.417128
# Epoch [3/150] Train Loss: 1.3709, Train Acc: 0.5131, Val Loss: 1.2606, Val Acc: 0.5479, Time: 0:00:29.318792
# Epoch [4/150] Train Loss: 1.2497, Train Acc: 0.5606, Val Loss: 1.1193, Val Acc: 0.6090, Time: 0:00:29.048406
# Epoch [5/150] Train Loss: 1.1620, Train Acc: 0.5929, Val Loss: 1.0278, Val Acc: 0.6389, Time: 0:00:29.230567
# Epoch [7/150] Train Loss: 1.0489, Train Acc: 0.6387, Val Loss: 0.9396, Val Acc: 0.6744, Time: 0:00:29.567080
# Epoch [8/150] Train Loss: 1.0074, Train Acc: 0.6547, Val Loss: 0.9188, Val Acc: 0.6730, Time: 0:00:29.144425
# Epoch [9/150] Train Loss: 0.9884, Train Acc: 0.6582, Val Loss: 0.8624, Val Acc: 0.7107, Time: 0:00:29.426229
# Epoch [10/150] Train Loss: 0.9573, Train Acc: 0.6709, Val Loss: 0.8490, Val Acc: 0.6977, Time: 0:00:29.175514
# Epoch [11/150] Train Loss: 0.9327, Train Acc: 0.6830, Val Loss: 0.8021, Val Acc: 0.7150, Time: 0:00:29.067598
# Epoch [12/150] Train Loss: 0.9137, Train Acc: 0.6900, Val Loss: 0.7761, Val Acc: 0.7283, Time: 0:00:29.362059
# Epoch [13/150] Train Loss: 0.8953, Train Acc: 0.6939, Val Loss: 0.7885, Val Acc: 0.7191, Time: 0:00:29.275630
# Epoch [14/150] Train Loss: 0.8758, Train Acc: 0.7024, Val Loss: 0.7658, Val Acc: 0.7406, Time: 0:00:29.153306
# Epoch [15/150] Train Loss: 0.8617, Train Acc: 0.7074, Val Loss: 0.7651, Val Acc: 0.7311, Time: 0:00:29.110866
# Epoch [16/150] Train Loss: 0.8428, Train Acc: 0.7126, Val Loss: 0.7495, Val Acc: 0.7338, Time: 0:00:29.116191
# Epoch [17/150] Train Loss: 0.8368, Train Acc: 0.7174, Val Loss: 0.7208, Val Acc: 0.7525, Time: 0:00:29.569547
# Epoch [18/150] Train Loss: 0.8181, Train Acc: 0.7211, Val Loss: 0.7046, Val Acc: 0.7533, Time: 0:00:29.488930
# Epoch [19/150] Train Loss: 0.8093, Train Acc: 0.7251, Val Loss: 0.6980, Val Acc: 0.7568, Time: 0:00:29.473275
# Epoch [20/150] Train Loss: 0.8007, Train Acc: 0.7266, Val Loss: 0.6650, Val Acc: 0.7727, Time: 0:00:29.082094
# Epoch [21/150] Train Loss: 0.7944, Train Acc: 0.7298, Val Loss: 0.6939, Val Acc: 0.7592, Time: 0:00:29.260739
# Epoch [22/150] Train Loss: 0.7801, Train Acc: 0.7340, Val Loss: 0.6904, Val Acc: 0.7576, Time: 0:00:29.373965
# Epoch [23/150] Train Loss: 0.7672, Train Acc: 0.7394, Val Loss: 0.6588, Val Acc: 0.7691, Time: 0:00:29.461080
# Epoch [24/150] Train Loss: 0.7611, Train Acc: 0.7411, Val Loss: 0.6574, Val Acc: 0.7764, Time: 0:00:29.401419
# Epoch [25/150] Train Loss: 0.7511, Train Acc: 0.7450, Val Loss: 0.6867, Val Acc: 0.7592, Time: 0:00:29.011972
# Epoch [26/150] Train Loss: 0.7500, Train Acc: 0.7456, Val Loss: 0.6563, Val Acc: 0.7742, Time: 0:00:29.140090
# Epoch [27/150] Train Loss: 0.7491, Train Acc: 0.7479, Val Loss: 0.6112, Val Acc: 0.7863, Time: 0:00:29.042332
# Epoch [28/150] Train Loss: 0.7353, Train Acc: 0.7498, Val Loss: 0.6318, Val Acc: 0.7744, Time: 0:00:29.354242
# Epoch [29/150] Train Loss: 0.7341, Train Acc: 0.7496, Val Loss: 0.6409, Val Acc: 0.7754, Time: 0:00:29.142028
# Epoch [30/150] Train Loss: 0.7247, Train Acc: 0.7533, Val Loss: 0.6160, Val Acc: 0.7871, Time: 0:00:29.960588
# Epoch [31/150] Train Loss: 0.7206, Train Acc: 0.7527, Val Loss: 0.6214, Val Acc: 0.7812, Time: 0:00:29.661932
# Epoch [32/150] Train Loss: 0.7167, Train Acc: 0.7562, Val Loss: 0.6193, Val Acc: 0.7934, Time: 0:00:29.383241
# Epoch [33/150] Train Loss: 0.7156, Train Acc: 0.7556, Val Loss: 0.6087, Val Acc: 0.7869, Time: 0:00:29.451489
# Epoch [34/150] Train Loss: 0.7028, Train Acc: 0.7612, Val Loss: 0.6239, Val Acc: 0.7893, Time: 0:00:29.134523
# Epoch [35/150] Train Loss: 0.7028, Train Acc: 0.7614, Val Loss: 0.6049, Val Acc: 0.7895, Time: 0:00:29.187872
# Epoch [36/150] Train Loss: 0.6971, Train Acc: 0.7635, Val Loss: 0.6054, Val Acc: 0.7879, Time: 0:00:29.056097
# Epoch [37/150] Train Loss: 0.6925, Train Acc: 0.7635, Val Loss: 0.6392, Val Acc: 0.7777, Time: 0:00:29.350190
# Epoch [38/150] Train Loss: 0.6893, Train Acc: 0.7655, Val Loss: 0.6130, Val Acc: 0.7852, Time: 0:00:29.163583
# Epoch [39/150] Train Loss: 0.6798, Train Acc: 0.7688, Val Loss: 0.5683, Val Acc: 0.8023, Time: 0:00:29.281157
# Epoch [40/150] Train Loss: 0.6807, Train Acc: 0.7687, Val Loss: 0.5805, Val Acc: 0.8014, Time: 0:00:29.276683
# Epoch [41/150] Train Loss: 0.6810, Train Acc: 0.7678, Val Loss: 0.5734, Val Acc: 0.7982, Time: 0:00:29.401210
# Epoch [42/150] Train Loss: 0.6806, Train Acc: 0.7706, Val Loss: 0.5824, Val Acc: 0.7949, Time: 0:00:29.336022
# Epoch [43/150] Train Loss: 0.6781, Train Acc: 0.7684, Val Loss: 0.5761, Val Acc: 0.8000, Time: 0:00:29.331729
# Epoch [44/150] Train Loss: 0.6755, Train Acc: 0.7709, Val Loss: 0.5794, Val Acc: 0.7990, Time: 0:00:29.754226
# Epoch [45/150] Train Loss: 0.6739, Train Acc: 0.7717, Val Loss: 0.5711, Val Acc: 0.8063, Time: 0:00:29.515155
# Epoch [46/150] Train Loss: 0.6604, Train Acc: 0.7754, Val Loss: 0.5599, Val Acc: 0.8068, Time: 0:00:29.313874
# Epoch [47/150] Train Loss: 0.6610, Train Acc: 0.7738, Val Loss: 0.5756, Val Acc: 0.7986, Time: 0:00:29.814103
# Epoch [48/150] Train Loss: 0.6669, Train Acc: 0.7726, Val Loss: 0.5616, Val Acc: 0.8018, Time: 0:00:29.383055
# Epoch [49/150] Train Loss: 0.6529, Train Acc: 0.7798, Val Loss: 0.5659, Val Acc: 0.7996, Time: 0:00:29.895040
# Epoch [50/150] Train Loss: 0.6554, Train Acc: 0.7757, Val Loss: 0.5699, Val Acc: 0.8045, Time: 0:00:29.675784
# Epoch [51/150] Train Loss: 0.6509, Train Acc: 0.7796, Val Loss: 0.5415, Val Acc: 0.8105, Time: 0:00:29.437447
# Epoch [52/150] Train Loss: 0.6498, Train Acc: 0.7814, Val Loss: 0.5616, Val Acc: 0.8033, Time: 0:00:29.829787
# Epoch [53/150] Train Loss: 0.6529, Train Acc: 0.7763, Val Loss: 0.5426, Val Acc: 0.8137, Time: 0:00:29.336107
# Epoch [54/150] Train Loss: 0.6490, Train Acc: 0.7793, Val Loss: 0.5633, Val Acc: 0.8053, Time: 0:00:29.219076
# Epoch [55/150] Train Loss: 0.6436, Train Acc: 0.7805, Val Loss: 0.5495, Val Acc: 0.8051, Time: 0:00:29.372414
# Epoch [56/150] Train Loss: 0.6458, Train Acc: 0.7811, Val Loss: 0.5673, Val Acc: 0.8057, Time: 0:00:29.592548
# Epoch [57/150] Train Loss: 0.6387, Train Acc: 0.7822, Val Loss: 0.5507, Val Acc: 0.8090, Time: 0:00:29.547039
# Epoch [58/150] Train Loss: 0.6444, Train Acc: 0.7799, Val Loss: 0.5549, Val Acc: 0.8023, Time: 0:00:29.287691
# Epoch [59/150] Train Loss: 0.6340, Train Acc: 0.7850, Val Loss: 0.5335, Val Acc: 0.8143, Time: 0:00:29.580782
# Epoch [60/150] Train Loss: 0.6325, Train Acc: 0.7830, Val Loss: 0.5404, Val Acc: 0.8115, Time: 0:00:30.104426
# Epoch [61/150] Train Loss: 0.6356, Train Acc: 0.7855, Val Loss: 0.5335, Val Acc: 0.8164, Time: 0:00:29.853725
# Epoch [62/150] Train Loss: 0.6304, Train Acc: 0.7828, Val Loss: 0.5422, Val Acc: 0.8039, Time: 0:00:29.733906
# Epoch [63/150] Train Loss: 0.6282, Train Acc: 0.7855, Val Loss: 0.5411, Val Acc: 0.8150, Time: 0:00:29.482748
# Epoch [64/150] Train Loss: 0.6266, Train Acc: 0.7849, Val Loss: 0.5507, Val Acc: 0.8053, Time: 0:00:30.551174
# Epoch [65/150] Train Loss: 0.6279, Train Acc: 0.7868, Val Loss: 0.5524, Val Acc: 0.8111, Time: 0:00:29.756946
# Epoch [66/150] Train Loss: 0.6248, Train Acc: 0.7873, Val Loss: 0.5330, Val Acc: 0.8160, Time: 0:00:29.605697
# Epoch [67/150] Train Loss: 0.6258, Train Acc: 0.7867, Val Loss: 0.5583, Val Acc: 0.8066, Time: 0:00:29.971409
# Epoch [68/150] Train Loss: 0.6256, Train Acc: 0.7885, Val Loss: 0.5359, Val Acc: 0.8090, Time: 0:00:29.748298
# Epoch [69/150] Train Loss: 0.6229, Train Acc: 0.7894, Val Loss: 0.5323, Val Acc: 0.8195, Time: 0:00:29.544182
# Epoch [70/150] Train Loss: 0.6203, Train Acc: 0.7897, Val Loss: 0.5145, Val Acc: 0.8178, Time: 0:00:29.410181
# Epoch [71/150] Train Loss: 0.6266, Train Acc: 0.7865, Val Loss: 0.5404, Val Acc: 0.8152, Time: 0:00:29.223808
# Epoch [72/150] Train Loss: 0.6178, Train Acc: 0.7890, Val Loss: 0.5095, Val Acc: 0.8262, Time: 0:00:29.523696
# Epoch [73/150] Train Loss: 0.6209, Train Acc: 0.7870, Val Loss: 0.5170, Val Acc: 0.8113, Time: 0:00:29.377242
# Epoch [74/150] Train Loss: 0.6215, Train Acc: 0.7893, Val Loss: 0.5314, Val Acc: 0.8201, Time: 0:00:29.377475
# Epoch [75/150] Train Loss: 0.6121, Train Acc: 0.7902, Val Loss: 0.5339, Val Acc: 0.8156, Time: 0:00:30.051115
# Epoch [76/150] Train Loss: 0.6138, Train Acc: 0.7900, Val Loss: 0.5296, Val Acc: 0.8221, Time: 0:00:29.224123
# Epoch [77/150] Train Loss: 0.6149, Train Acc: 0.7905, Val Loss: 0.5333, Val Acc: 0.8133, Time: 0:00:29.350299
# Epoch [78/150] Train Loss: 0.6170, Train Acc: 0.7900, Val Loss: 0.5302, Val Acc: 0.8219, Time: 0:00:29.746756
# Epoch [79/150] Train Loss: 0.6147, Train Acc: 0.7913, Val Loss: 0.5145, Val Acc: 0.8234, Time: 0:00:29.663332
# Epoch [80/150] Train Loss: 0.6102, Train Acc: 0.7924, Val Loss: 0.5234, Val Acc: 0.8162, Time: 0:00:29.327432
# Epoch [81/150] Train Loss: 0.6121, Train Acc: 0.7919, Val Loss: 0.5169, Val Acc: 0.8158, Time: 0:00:29.783275
# Epoch [82/150] Train Loss: 0.6143, Train Acc: 0.7896, Val Loss: 0.5386, Val Acc: 0.8096, Time: 0:00:29.705746
# Epoch [83/150] Train Loss: 0.6100, Train Acc: 0.7941, Val Loss: 0.5251, Val Acc: 0.8225, Time: 0:00:29.843596
# Epoch [84/150] Train Loss: 0.5715, Train Acc: 0.8057, Val Loss: 0.4847, Val Acc: 0.8320, Time: 0:00:29.211181
# Epoch [85/150] Train Loss: 0.5585, Train Acc: 0.8101, Val Loss: 0.4857, Val Acc: 0.8314, Time: 0:00:29.305204
# Epoch [86/150] Train Loss: 0.5548, Train Acc: 0.8128, Val Loss: 0.4705, Val Acc: 0.8342, Time: 0:00:29.479612
# Epoch [87/150] Train Loss: 0.5472, Train Acc: 0.8133, Val Loss: 0.4854, Val Acc: 0.8344, Time: 0:00:29.257289
# Epoch [88/150] Train Loss: 0.5451, Train Acc: 0.8132, Val Loss: 0.4926, Val Acc: 0.8285, Time: 0:00:29.723391
# Epoch [89/150] Train Loss: 0.5418, Train Acc: 0.8162, Val Loss: 0.4761, Val Acc: 0.8369, Time: 0:00:29.542866
# Epoch [90/150] Train Loss: 0.5360, Train Acc: 0.8159, Val Loss: 0.4749, Val Acc: 0.8369, Time: 0:00:29.840303
# Epoch [91/150] Train Loss: 0.5301, Train Acc: 0.8184, Val Loss: 0.4792, Val Acc: 0.8318, Time: 0:00:29.793495
# Epoch [92/150] Train Loss: 0.5371, Train Acc: 0.8161, Val Loss: 0.4548, Val Acc: 0.8406, Time: 0:00:29.492388
# Epoch [93/150] Train Loss: 0.5327, Train Acc: 0.8187, Val Loss: 0.4572, Val Acc: 0.8412, Time: 0:00:29.177561
# Epoch [94/150] Train Loss: 0.5306, Train Acc: 0.8182, Val Loss: 0.4496, Val Acc: 0.8467, Time: 0:00:30.002756
# Epoch [95/150] Train Loss: 0.5261, Train Acc: 0.8210, Val Loss: 0.4671, Val Acc: 0.8408, Time: 0:00:29.698975
# Epoch [96/150] Train Loss: 0.5245, Train Acc: 0.8211, Val Loss: 0.4685, Val Acc: 0.8430, Time: 0:00:29.335843
# Epoch [97/150] Train Loss: 0.5227, Train Acc: 0.8216, Val Loss: 0.4515, Val Acc: 0.8400, Time: 0:00:29.610280
# Epoch [98/150] Train Loss: 0.5302, Train Acc: 0.8194, Val Loss: 0.4576, Val Acc: 0.8428, Time: 0:00:29.452472
# Epoch [99/150] Train Loss: 0.5246, Train Acc: 0.8196, Val Loss: 0.4623, Val Acc: 0.8424, Time: 0:00:29.508282
# Epoch [100/150] Train Loss: 0.5258, Train Acc: 0.8218, Val Loss: 0.4537, Val Acc: 0.8438, Time: 0:00:29.582517
# Epoch [101/150] Train Loss: 0.5272, Train Acc: 0.8194, Val Loss: 0.4421, Val Acc: 0.8484, Time: 0:00:29.350570
# Epoch [102/150] Train Loss: 0.5244, Train Acc: 0.8215, Val Loss: 0.4503, Val Acc: 0.8432, Time: 0:00:29.566547
# Epoch [103/150] Train Loss: 0.5230, Train Acc: 0.8198, Val Loss: 0.4392, Val Acc: 0.8484, Time: 0:00:29.519064
# Epoch [104/150] Train Loss: 0.5134, Train Acc: 0.8234, Val Loss: 0.4531, Val Acc: 0.8426, Time: 0:00:29.589041
# Epoch [105/150] Train Loss: 0.5231, Train Acc: 0.8220, Val Loss: 0.4518, Val Acc: 0.8467, Time: 0:00:29.656265
# Epoch [106/150] Train Loss: 0.5185, Train Acc: 0.8238, Val Loss: 0.4530, Val Acc: 0.8375, Time: 0:00:29.100496
# Epoch [107/150] Train Loss: 0.5225, Train Acc: 0.8218, Val Loss: 0.4465, Val Acc: 0.8434, Time: 0:00:29.228070
# Epoch [108/150] Train Loss: 0.5187, Train Acc: 0.8233, Val Loss: 0.4537, Val Acc: 0.8457, Time: 0:00:30.011569
# Epoch [109/150] Train Loss: 0.5162, Train Acc: 0.8227, Val Loss: 0.4668, Val Acc: 0.8342, Time: 0:00:29.769535
# Epoch [110/150] Train Loss: 0.5077, Train Acc: 0.8238, Val Loss: 0.4632, Val Acc: 0.8402, Time: 0:00:29.552122
# Epoch [111/150] Train Loss: 0.5140, Train Acc: 0.8231, Val Loss: 0.4422, Val Acc: 0.8457, Time: 0:00:29.406544
# Epoch [112/150] Train Loss: 0.5137, Train Acc: 0.8245, Val Loss: 0.4194, Val Acc: 0.8539, Time: 0:00:29.679770
# Epoch [113/150] Train Loss: 0.5168, Train Acc: 0.8223, Val Loss: 0.4585, Val Acc: 0.8414, Time: 0:00:29.505606
# Epoch [114/150] Train Loss: 0.5136, Train Acc: 0.8242, Val Loss: 0.4685, Val Acc: 0.8373, Time: 0:00:29.275690
# Epoch [115/150] Train Loss: 0.5118, Train Acc: 0.8256, Val Loss: 0.4457, Val Acc: 0.8457, Time: 0:00:29.191229
# Epoch [116/150] Train Loss: 0.5112, Train Acc: 0.8264, Val Loss: 0.4416, Val Acc: 0.8457, Time: 0:00:29.645597
# Epoch [117/150] Train Loss: 0.5088, Train Acc: 0.8274, Val Loss: 0.4534, Val Acc: 0.8387, Time: 0:00:29.578304
# Epoch [118/150] Train Loss: 0.5108, Train Acc: 0.8242, Val Loss: 0.4515, Val Acc: 0.8480, Time: 0:00:29.443653
# Epoch [119/150] Train Loss: 0.5003, Train Acc: 0.8294, Val Loss: 0.4378, Val Acc: 0.8490, Time: 0:00:29.434763
# Epoch [120/150] Train Loss: 0.5105, Train Acc: 0.8269, Val Loss: 0.4402, Val Acc: 0.8475, Time: 0:00:29.357813
# Epoch [121/150] Train Loss: 0.5117, Train Acc: 0.8243, Val Loss: 0.4502, Val Acc: 0.8475, Time: 0:00:29.214391
# Epoch [122/150] Train Loss: 0.5137, Train Acc: 0.8248, Val Loss: 0.4508, Val Acc: 0.8375, Time: 0:00:29.364638
# Epoch [123/150] Train Loss: 0.4998, Train Acc: 0.8301, Val Loss: 0.4341, Val Acc: 0.8500, Time: 0:00:29.336006
# Epoch [124/150] Train Loss: 0.4882, Train Acc: 0.8338, Val Loss: 0.4288, Val Acc: 0.8508, Time: 0:00:29.417634
# Epoch [125/150] Train Loss: 0.4807, Train Acc: 0.8351, Val Loss: 0.4234, Val Acc: 0.8557, Time: 0:00:29.893717
# Epoch [126/150] Train Loss: 0.4764, Train Acc: 0.8375, Val Loss: 0.4219, Val Acc: 0.8564, Time: 0:00:29.757436
# Epoch [127/150] Train Loss: 0.4780, Train Acc: 0.8366, Val Loss: 0.4371, Val Acc: 0.8496, Time: 0:00:29.780842
# Epoch [128/150] Train Loss: 0.4692, Train Acc: 0.8380, Val Loss: 0.4283, Val Acc: 0.8539, Time: 0:00:29.528639
# Epoch [129/150] Train Loss: 0.4669, Train Acc: 0.8410, Val Loss: 0.4389, Val Acc: 0.8475, Time: 0:00:29.161764
# Epoch [130/150] Train Loss: 0.4671, Train Acc: 0.8386, Val Loss: 0.4228, Val Acc: 0.8576, Time: 0:00:29.447859
# Epoch [131/150] Train Loss: 0.4642, Train Acc: 0.8411, Val Loss: 0.4136, Val Acc: 0.8539, Time: 0:00:29.099096
# Epoch [132/150] Train Loss: 0.4684, Train Acc: 0.8394, Val Loss: 0.4221, Val Acc: 0.8584, Time: 0:00:29.250496
# Epoch [133/150] Train Loss: 0.4673, Train Acc: 0.8390, Val Loss: 0.4126, Val Acc: 0.8660, Time: 0:00:29.405978
# Epoch [134/150] Train Loss: 0.4564, Train Acc: 0.8437, Val Loss: 0.4096, Val Acc: 0.8602, Time: 0:00:29.226102
# Epoch [135/150] Train Loss: 0.4555, Train Acc: 0.8428, Val Loss: 0.4320, Val Acc: 0.8490, Time: 0:00:29.212404
# Epoch [136/150] Train Loss: 0.4576, Train Acc: 0.8425, Val Loss: 0.4239, Val Acc: 0.8488, Time: 0:00:29.950878
# Epoch [137/150] Train Loss: 0.4613, Train Acc: 0.8420, Val Loss: 0.4037, Val Acc: 0.8576, Time: 0:00:29.593571
# Epoch [138/150] Train Loss: 0.4551, Train Acc: 0.8440, Val Loss: 0.4354, Val Acc: 0.8555, Time: 0:00:29.373435
# Epoch [139/150] Train Loss: 0.4545, Train Acc: 0.8427, Val Loss: 0.4148, Val Acc: 0.8547, Time: 0:00:29.234818
# Epoch [140/150] Train Loss: 0.4540, Train Acc: 0.8435, Val Loss: 0.4070, Val Acc: 0.8621, Time: 0:00:29.300139
# Epoch [141/150] Train Loss: 0.4518, Train Acc: 0.8460, Val Loss: 0.4062, Val Acc: 0.8604, Time: 0:00:29.390928
# Epoch [142/150] Train Loss: 0.4545, Train Acc: 0.8425, Val Loss: 0.4395, Val Acc: 0.8432, Time: 0:00:29.925271
# Epoch [143/150] Train Loss: 0.4533, Train Acc: 0.8450, Val Loss: 0.4210, Val Acc: 0.8557, Time: 0:00:29.160867
# Epoch [144/150] Train Loss: 0.4447, Train Acc: 0.8469, Val Loss: 0.4100, Val Acc: 0.8588, Time: 0:00:29.370323
# Epoch [145/150] Train Loss: 0.4455, Train Acc: 0.8470, Val Loss: 0.4189, Val Acc: 0.8537, Time: 0:00:29.927339
# Epoch [146/150] Train Loss: 0.4526, Train Acc: 0.8456, Val Loss: 0.4022, Val Acc: 0.8607, Time: 0:00:29.164868
# Epoch [147/150] Train Loss: 0.4509, Train Acc: 0.8448, Val Loss: 0.4165, Val Acc: 0.8580, Time: 0:00:29.036060
# Epoch [148/150] Train Loss: 0.4462, Train Acc: 0.8464, Val Loss: 0.4117, Val Acc: 0.8613, Time: 0:00:29.164382
# Epoch [149/150] Train Loss: 0.4503, Train Acc: 0.8458, Val Loss: 0.4235, Val Acc: 0.8537, Time: 0:00:29.048556
# Epoch [150/150] Train Loss: 0.4485, Train Acc: 0.8460, Val Loss: 0.4177, Val Acc: 0.8580, Time: 0:00:29.132115
# Training Time: 0:00:29.135177
#
# Test Loss Model 4: 0.2845, Test Acc: 0.9046
